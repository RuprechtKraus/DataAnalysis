# %%
import pandas as pd
import matplotlib.pyplot as plt
import io

# %% [markdown]
# Файл sales_train.csv содержит индексы продаж по дням за период 2008 - 2017

# %%
df_sales_train = pd.read_csv("sales_train.csv")
df_sales_train
# Out:
#             date  market_1  market_2  market_3  market_4  market_5  market_6  \
# 0     2008-01-02  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1     2008-01-03       NaN  1.006943  1.002595  1.006953  1.014819       NaN
# 2     2008-01-04  1.015188       NaN  1.043535  1.044507  1.050865  1.025508
# 3     2008-01-05       NaN  1.045076       NaN  1.080214  1.071665       NaN
# 4     2008-01-06  0.995762  1.000988  1.051633  1.056388  1.047756  1.002896
# ...          ...       ...       ...       ...       ...       ...       ...
# 2916  2015-12-27  2.162458       NaN  2.515498  3.871723  4.061596       NaN
# 2917  2015-12-28       NaN  3.425255  2.525145       NaN  4.057857  3.835661
# 2918  2015-12-29  2.164239       NaN  2.524327  3.883184  4.056121  3.852841
# 2919  2015-12-30  2.168029  3.435747  2.538544  3.893227  4.062142  3.855567
# 2920  2015-12-31       NaN  3.424718  2.545287  3.887936  4.059624  3.847464
#
#       market_7  market_8
# ...

# %%
df_sales_train.describe()
# Out:
#           market_1     market_2     market_3     market_4     market_5  \
# count  2318.000000  2320.000000  2355.000000  2320.000000  2347.000000
# mean      1.679924     2.382302     1.785479     2.084432     2.351293
# std       0.415762     0.603411     0.435667     0.924918     0.829402
# min       0.937147     0.989628     0.951383     0.862978     1.000000
# 25%       1.339669     1.905707     1.465732     1.319057     1.634398
# 50%       1.656322     2.316259     1.706630     1.844848     2.120974
# 75%       1.977632     2.817650     2.028506     2.453868     2.994378
# max       2.766316     3.814635     3.037881     4.272993     4.394967
#
#           market_6     market_7     market_8
# count  2301.000000  2348.000000  2370.000000
# mean      2.310386     1.788906     2.545632
# std       0.898197     0.742181     0.924786
# min       0.856543     0.558537     0.894445
# 25%       1.504911     1.202137     1.840781
# 50%       2.196724     1.625944     2.409829
# ...

# %% [markdown]
# Следующая таблица описывает количество отсутствующих данных по каждому магазину

# %%
df_sales_train.isnull().sum()
# Out:
# date          0
# market_1    603
# market_2    601
# market_3    566
# market_4    601
# market_5    574
# market_6    620
# market_7    573
# market_8    551
# dtype: int64

# %%
df_sales_train.hist()
# Out:
# array([[<AxesSubplot:title={'center':'market_1'}>,
#         <AxesSubplot:title={'center':'market_2'}>,
#         <AxesSubplot:title={'center':'market_3'}>],
#        [<AxesSubplot:title={'center':'market_4'}>,
#         <AxesSubplot:title={'center':'market_5'}>,
#         <AxesSubplot:title={'center':'market_6'}>],
#        [<AxesSubplot:title={'center':'market_7'}>,
#         <AxesSubplot:title={'center':'market_8'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# Файл advert_train.csv содержит данные о рекламных акциях в каждом магазине. Обозначены как 1 в соответствующую дату

# %%
df_advert_train = pd.read_csv("advert_train.csv")
df_advert_train
# Out:
#             date  market_1  market_2  market_3  market_4  market_5  market_6  \
# 0     2008-01-02         0         0         0         0         0         0
# 1     2008-01-03         0         0         0         0         0         0
# 2     2008-01-04         0         0         0         0         0         0
# 3     2008-01-05         0         0         0         0         0         0
# 4     2008-01-06         0         0         0         0         0         0
# ...          ...       ...       ...       ...       ...       ...       ...
# 2916  2015-12-27         0         0         0         0         0         0
# 2917  2015-12-28         0         0         0         0         0         0
# 2918  2015-12-29         0         0         0         0         0         0
# 2919  2015-12-30         0         0         0         0         0         0
# 2920  2015-12-31         0         0         0         0         0         0
#
#       market_7  market_8
# ...

# %% [markdown]
# Количество акций по каждому магазину за все время наблюдения

# %%
df_advert_train.sum()
# Out:
# date        2008-01-022008-01-032008-01-042008-01-052008-0...
# market_1                                                    6
# market_2                                                    4
# market_3                                                    8
# market_4                                                    2
# market_5                                                    6
# market_6                                                    2
# market_7                                                    9
# market_8                                                    9
# dtype: object

# %% [markdown]
# Файл advert_test.csv содержин данные о рекламных акциях на тестовом периоде 2016-2018

# %%
df_advert_test = pd.read_csv("advert_test.csv")
df_advert_test
# Out:
#            date  market_1  market_2  market_3  market_4  market_5  market_6  \
# 0    2016-01-01         0         0         0         0         0         0
# 1    2016-01-02         0         0         0         0         0         0
# 2    2016-01-03         0         0         0         0         0         0
# 3    2016-01-04         0         0         0         0         0         0
# 4    2016-01-05         0         0         0         0         0         0
# ..          ...       ...       ...       ...       ...       ...       ...
# 724  2017-12-25         0         0         0         0         0         0
# 725  2017-12-26         0         0         0         0         0         0
# 726  2017-12-27         0         0         0         0         0         0
# 727  2017-12-28         0         0         0         0         0         0
# 728  2017-12-29         0         0         0         0         0         0
#
#      market_7  market_8
# 0           0         0
# ...

# %% [markdown]
# Количество акций в магазинах за этот период

# %%
df_advert_test.sum()
# Out:
# date        2016-01-012016-01-022016-01-032016-01-042016-0...
# market_1                                                    2
# market_2                                                    2
# market_3                                                    2
# market_4                                                    2
# market_5                                                    0
# market_6                                                    0
# market_7                                                    1
# market_8                                                    2
# dtype: object
